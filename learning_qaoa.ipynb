# %%
import matplotlib
import matplotlib.pyplot as plt
import rustworkx as rx
from rustworkx.visualization import mpl_draw as draw_graph
import numpy as np
from scipy.optimize import minimize
from collections import defaultdict
from typing import Sequence
 
 
from qiskit.quantum_info import SparsePauliOp
from qiskit.circuit.library import QAOAAnsatz
from qiskit.transpiler.preset_passmanagers import generate_preset_pass_manager
 
from qiskit_ibm_runtime import QiskitRuntimeService
from qiskit_ibm_runtime import Session, EstimatorV2 as Estimator
from qiskit_ibm_runtime import SamplerV2 as Sampler

# %%
n = 5
 
graph = rx.PyGraph()
graph.add_nodes_from(np.arange(0, n, 1))
edge_list = [
    (0, 1, 1.0),
    (0, 2, 1.0),
    (0, 4, 1.0),
    (1, 2, 1.0),
    (2, 3, 1.0),
    (3, 4, 1.0),
]
graph.add_edges_from(edge_list)
draw_graph(graph, node_size=600, with_labels=True)

# %%
def build_max_cut_paulis(graph: rx.PyGraph) -> list[tuple[str, float]]:
    """Convert the graph to Pauli list.
 
    This function does the inverse of `build_max_cut_graph`
    """
    pauli_list = []
    for edge in list(graph.edge_list()):
        weight = graph.get_edge_data(edge[0], edge[1])
        pauli_list.append(("ZZ", [edge[0], edge[1]], weight))
    return pauli_list
 
 
max_cut_paulis = build_max_cut_paulis(graph)
cost_hamiltonian = SparsePauliOp.from_sparse_list(max_cut_paulis, n)
print("Cost Function Hamiltonian:", cost_hamiltonian)
# Out:
# Cost Function Hamiltonian: SparsePauliOp(['IIIZZ', 'IIZIZ', 'ZIIIZ', 'IIZZI', 'IZZII', 'ZZIII'],
#               coeffs=[1.+0.j, 1.+0.j, 1.+0.j, 1.+0.j, 1.+0.j, 1.+0.j])

# %%
circuit = QAOAAnsatz(cost_operator=cost_hamiltonian, reps=2)
circuit.measure_all()
 
circuit.draw("mpl")

# %%
circuit.parameters
# Out:
# ParameterView([ParameterVectorElement(β[0]), ParameterVectorElement(β[1]), ParameterVectorElement(γ[0]), ParameterVectorElement(γ[1])])

# %%
service = QiskitRuntimeService()
backend = service.least_busy(
    operational=True, simulator=False, min_num_qubits=127
)
print(backend)
 
# Create pass manager for transpilation
pm = generate_preset_pass_manager(optimization_level=3, backend=backend)
 
candidate_circuit = pm.run(circuit)
candidate_circuit.draw("mpl", fold=False, idle_wires=False)
# Out:
# qiskit_runtime_service.__init__:WARNING:2026-01-02 13:32:24,467: Instance was not set at service instantiation. Free and trial plan instances will be prioritized. Based on the following filters: (tags: None, region: us-east, eu-de), and available plans: (open), the available account instances are: open-instance. If you need a specific instance set it explicitly either by using a saved account with a saved default instance or passing it in directly to QiskitRuntimeService().
# qiskit_runtime_service.backends:WARNING:2026-01-02 13:32:25,251: Loading instance: open-instance, plan: open
# qiskit_runtime_service.backends:WARNING:2026-01-02 13:32:27,443: Using instance: open-instance, plan: open
# <IBMBackend('ibm_fez')>

# %%
initial_gamma = np.pi
initial_beta = np.pi / 2
init_params = [initial_beta, initial_beta, initial_gamma, initial_gamma]

# %%
def cost_func_estimator(params, ansatz, hamiltonian, estimator):
    # transform the observable defined on virtual qubits to
    # an observable defined on all physical qubits
    isa_hamiltonian = hamiltonian.apply_layout(ansatz.layout)
 
    pub = (ansatz, isa_hamiltonian, params)
    job = estimator.run([pub])
 
    results = job.result()[0]
    cost = results.data.evs
 
    objective_func_vals.append(cost)
 
    return cost

# %%
objective_func_vals = []  # Global variable
with Session(backend=backend) as session:
    # If using qiskit-ibm-runtime<0.24.0, change `mode=` to `session=`
    estimator = Estimator(mode=session)
    estimator.options.default_shots = 1000
 
    # Set simple error suppression/mitigation options
    estimator.options.dynamical_decoupling.enable = True
    estimator.options.dynamical_decoupling.sequence_type = "XY4"
    estimator.options.twirling.enable_gates = True
    estimator.options.twirling.num_randomizations = "auto"
 
    result = minimize(
        cost_func_estimator,
        init_params,
        args=(candidate_circuit, cost_hamiltonian, estimator),
        method="COBYLA",
        tol=1e-2,
    )
    print(result)
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# File c:\Users\Prüfer\OneDrive - Leuphana University\Desktop\Quanten_benchmarking\venv_cplex\lib\site-packages\qiskit_ibm_runtime\api\session.py:329, in RetrySession.request(self, method, url, bare, **kwargs)
#     328     response = super().request(method, final_url, headers=headers, **kwargs)
# --> 329     response.raise_for_status()
#     330 except RequestException as ex:
#     331     # Wrap the requests exceptions into a IBM Q custom one, for
#     332     # compatibility.
#
# File c:\Users\Prüfer\OneDrive - Leuphana University\Desktop\Quanten_benchmarking\venv_cplex\lib\site-packages\requests\models.py:1026, in Response.raise_for_status(self)
#    1025 if http_error_msg:
# -> 1026     raise HTTPError(http_error_msg, response=self)
#
# HTTPError: 400 Client Error: Bad Request for url: https://quantum.cloud.ibm.com/api/v1/sessions
#
# The above exception was the direct cause of the following exception:
#
# RequestsApiError                          Traceback (most recent call last)
# Cell In[9], line 2
#       1 objective_func_vals = []  # Global variable
# ----> 2 with Session(backend=backend) as session:
#       3     # If using qiskit-ibm-runtime<0.24.0, change `mode=` to `session=`
#       4     estimator = Estimator(mode=session)
#       5     estimator.options.default_shots = 1000
#
# File c:\Users\Prüfer\OneDrive - Leuphana University\Desktop\Quanten_benchmarking\venv_cplex\lib\site-packages\qiskit_ibm_runtime\session.py:131, in Session.__init__(self, backend, max_time, create_new)
#     129 self._instance = self._backend._instance
#     130 if not self._backend.configuration().simulator:
# --> 131     self._session_id = self._create_session(create_new=create_new)
#
# File c:\Users\Prüfer\OneDrive - Leuphana University\Desktop\Quanten_benchmarking\venv_cplex\lib\site-packages\qiskit_ibm_runtime\session.py:136, in Session._create_session(self, create_new)
#     134 """Create a session."""
#     135 if isinstance(self._service, QiskitRuntimeService) and create_new:
# --> 136     session = self._service._get_api_client(self._instance).create_session(
#     137         self.backend(), self._instance, self._max_time, "dedicated"
#     138     )
#     139     return session.get("id")
#     140 return None
#
# File c:\Users\Prüfer\OneDrive - Leuphana University\Desktop\Quanten_benchmarking\venv_cplex\lib\site-packages\qiskit_ibm_runtime\api\clients\runtime.py:222, in RuntimeClient.create_session(self, backend, instance, max_time, mode)
#     210 def create_session(
#     211     self,
#     212     backend: str | None = None,
#    (...)
#     215     mode: str | None = None,
#     216 ) -> dict[str, Any]:
#     217     """Create a session.
#     218
#     219     Args:
#     220         mode: Execution mode.
#     221     """
# --> 222     return self._api.runtime_session(session_id=None).create(backend, instance, max_time, mode)
#
# File c:\Users\Prüfer\OneDrive - Leuphana University\Desktop\Quanten_benchmarking\venv_cplex\lib\site-packages\qiskit_ibm_runtime\api\rest\runtime_session.py:61, in RuntimeSession.create(self, backend, instance, max_time, mode)
#      59 if max_time:
#      60     payload["max_ttl"] = max_time  # type: ignore[assignment]
# ---> 61 return self.session.post(url, json=payload, headers=self._HEADER_JSON_CONTENT).json()
#
# File c:\Users\Prüfer\OneDrive - Leuphana University\Desktop\Quanten_benchmarking\venv_cplex\lib\site-packages\requests\sessions.py:637, in Session.post(self, url, data, json, **kwargs)
#     626 def post(self, url, data=None, json=None, **kwargs):
#     627     r"""Sends a POST request. Returns :class:`Response` object.
#     628
#     629     :param url: URL for the new :class:`Request` object.
#    (...)
#     634     :rtype: requests.Response
#     635     """
# --> 637     return self.request("POST", url, data=data, json=json, **kwargs)
#
# File c:\Users\Prüfer\OneDrive - Leuphana University\Desktop\Quanten_benchmarking\venv_cplex\lib\site-packages\qiskit_ibm_runtime\api\session.py:357, in RetrySession.request(self, method, url, bare, **kwargs)
#     351     if status_code == 503:  # Planned maintenance outage
#     352         raise RequestsApiError(
#     353             "Unexpected response received from server. Please check if the service "
#     354             "is in maintenance mode "
#     355             f"https://docs.quantum.ibm.com/announcements/service-alerts {message}"
#     356         )
# --> 357     raise RequestsApiError(message, status_code) from ex
#     359 return response
#
# RequestsApiError: '400 Client Error: Bad Request for url: https://quantum.cloud.ibm.com/api/v1/sessions. {"errors":[{"code":1352,"message":"You are not authorized to run a session when using the open plan.","solution":"Create an instance of a different plan type or use a different [execution mode](https://quantum.cloud.ibm.com/docs/guides/execution-modes).","more_info":"https://cloud.ibm.com/apidocs/quantum-computing#error-handling"}],"trace":"d5dd08d2-b483-41e9-8d88-e8d2949afe66"}\n'

# %%
plt.figure(figsize=(12, 6))
plt.plot(objective_func_vals)
plt.xlabel("Iteration")
plt.ylabel("Cost")
plt.show()
